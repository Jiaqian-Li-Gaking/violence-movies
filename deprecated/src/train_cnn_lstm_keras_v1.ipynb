# %% [markdown]
# ### Modify the 3dcnnlstm model

# %% [markdown]
# ### 1. Load data

# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)

gpus = tf.config.list_physical_devices('GPU')
print("GPUs:", gpus)
# Out:
# 2026-01-27 09:58:40.974629: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-27 09:58:41.532819: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-27 09:58:56.574385: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# /mnt/d/Myworkplace/Python/violence-movies/.venv/lib/python3.12/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# TensorFlow version: 2.20.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv3D, MaxPooling3D, Flatten, Dense, LSTM, TimeDistributed, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, roc_curve, auc, roc_auc_score
from pathlib import Path
import gc

try:
    BASE_DIR = Path(__file__).resolve().parent.parent
except NameError:
    # Jupyter notebook fallback
    BASE_DIR = Path.cwd().parent

def load_data(folders, labels, base_path, frame_count=10):
    data = []
    targets = []
    for folder in folders:
        folder_path = os.path.join(base_path, folder)
        for video_folder in os.listdir(folder_path):
            video_path = os.path.join(folder_path, video_folder)
            frames = []
            for frame_file in sorted(os.listdir(video_path))[:frame_count]:
                frame_path = os.path.join(video_path, frame_file)
                frame = cv2.imread(frame_path)
                frame = cv2.resize(frame, (112, 112))
                frames.append(frame)

            # for i, frame in enumerate(frames):
            #     cv2.imshow("Resized Frame (64x64)", frame)
            #     key = cv2.waitKey(0)
            #     if key == 27:  # ESC
            #         cv2.destroyAllWindows()
            #         return None, None  # stop after first video
            # cv2.destroyAllWindows()

            if len(frames) < frame_count:
                frames.extend([np.zeros_like(frames[0])]*(frame_count - len(frames)))
            data.append(frames)
            targets.append(labels[folder])
    return np.array(data), np.array(targets)

base_path = BASE_DIR / "data" / "processed" / "violence-detection-dataset"
folders = ["high-level violence_frames", "low-level violence_frames", "non-violence_frames"]
labels = {"high-level violence_frames": 0, "low-level violence_frames": 1, "non-violence_frames": 2}

data, targets = load_data(folders, labels, base_path)
data = data / 255.0

print(f"Data shape: {data.shape}")
print(f"Targets shape: {targets.shape}")
# Out:
# Data shape: (350, 10, 112, 112, 3)
# Targets shape: (350,)

# %% [markdown]
# ### 2. Create model

# %%
# change maxpooling3D from (2,2,2) to (1,2,2)
def create_model(input_shape, num_classes, conv_filters, lstm_units, dropout_rate=0.5):
    # (batch, 10, 64, 64, 3)
    inputs = Input(shape=input_shape)
    # (batch, 10, 64, 64, conv_filters)
    x = Conv3D(conv_filters, (3, 3, 3), activation='relu', padding='same')(inputs)
    # (batch, 10, 32, 32, conv_filters)
    x = MaxPooling3D((1, 2, 2))(x)
    
    # (batch, 10, 32, 32, conv_filters)
    x = Conv3D(conv_filters, (3, 3, 3), activation='relu', padding='same')(x)
    # (batch, 10, 16, 16, conv_filters)
    x = MaxPooling3D((1, 2, 2))(x)

    # (batch, 10, 16, 16, conv_filters)
    x = Conv3D(conv_filters, (3, 3, 3), activation='relu', padding='same')(x)
    # (batch, 10, 8, 8, conv_filters)
    x = MaxPooling3D((1, 2, 2))(x)
    
    # (batch, 10, conv_filters)
    x = TimeDistributed(GlobalAveragePooling2D())(x)
    # (batch, lstm_units)
    x = LSTM(lstm_units)(x)
    x = Dropout(dropout_rate)(x)
    # (batch, 256)
    x = Dense(256, activation='relu')(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs, outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    return model

input_shape = (10, 112, 112, 3)
num_classes = 3
conv_filters_list = [32, 64, 128]
lstm_units_list = [64, 128]
# conv_filters_list = [64]
# lstm_units_list = [64]
# conv_filters_list = [128]
# lstm_units_list = [128]
dropout_rate_list = [0.2,0.3,0.4,0.5]
results_neurons = {}

# early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
mean_fpr = np.linspace(0, 1, 100)

# %% [markdown]
# ### 3. Train

# %%
for conv_filters in conv_filters_list:
    for lstm_units in lstm_units_list:
        f1_scores = []
        roc_aucs = []
        tprs = []
        histories = []

        for fold, (train_index, val_index) in enumerate(kf.split(data, targets), start=1):
        # for train_index, val_index in kf.split(data, targets):
            X_train, X_val = data[train_index], data[val_index]
            y_train, y_val = targets[train_index], targets[val_index]

            print(f"\n[Fold {fold}]")

            early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
            model = create_model(input_shape, num_classes, conv_filters, lstm_units)
            history = model.fit(X_train, y_train, validation_data=(X_val, y_val), 
                                epochs=80, batch_size=8, callbacks=[early_stopping])
            histories.append(history.history)

            y_val_pred = model.predict(X_val, batch_size=8, verbose=0)
            y_val_pred_classes = np.argmax(y_val_pred, axis=1)

            print("pred:", np.bincount(y_val_pred_classes, minlength=num_classes))

            f1 = f1_score(y_val, y_val_pred_classes, average='weighted')
            f1_scores.append(f1)

            fpr, tpr, _ = roc_curve(y_val, y_val_pred_classes, pos_label=2)
            roc_auc = auc(fpr, tpr)
            roc_aucs.append(roc_auc)
            tprs.append(np.interp(mean_fpr, fpr, tpr))
            tprs[-1][0] = 0.0

            # discard fold model
            K.clear_session()
            del model
            gc.collect()

        mean_tpr = np.mean(tprs, axis=0)
        mean_tpr[-1] = 1.0
        mean_auc = auc(mean_fpr, mean_tpr)

        results_neurons[f'conv_filters_{conv_filters}_lstm_units_{lstm_units}'] = {
            'histories': histories,
            'mean_f1_score': np.mean(f1_scores),
            'mean_auc': np.mean(roc_aucs),
            'mean_tpr': mean_tpr,
            'mean_fpr': mean_fpr,
            'mean_auc_curve': mean_auc
        }

        print(f"Model with conv_filters={conv_filters} and lstm_units={lstm_units} saved.")
        print(f"Average F1-Score: {np.mean(f1_scores):.4f}")
        print(f"Average AUC: {np.mean(roc_aucs):.4f}")
# Out:
# [Fold 1]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1769479255.846219    2347 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5520 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/80
# 2026-01-27 10:01:00.049830: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - accuracy: 0.3333 - loss: 1.0995 - val_accuracy: 0.3714 - val_loss: 1.0946
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.3778 - loss: 1.0958 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.3206 - loss: 1.0963 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.3714 - loss: 1.0966 - val_accuracy: 0.3714 - val_loss: 1.0931
# Epoch 5/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.3587 - loss: 1.0963 - val_accuracy: 0.3714 - val_loss: 1.0932
# Epoch 6/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3714 - loss: 1.0954 - val_accuracy: 0.3714 - val_loss: 1.0927
# Epoch 7/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3714 - loss: 1.0963 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 8/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3714 - loss: 1.0939 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 9/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.3714 - loss: 1.0932 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 10/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.3460 - loss: 1.0928 - val_accuracy: 0.4286 - val_loss: 1.0921
# Epoch 11/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3937 - loss: 1.0919 - val_accuracy: 0.3714 - val_loss: 1.0943
# Epoch 12/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3873 - loss: 1.0856 - val_accuracy: 0.3429 - val_loss: 1.1043
# Epoch 13/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3905 - loss: 1.0775 - val_accuracy: 0.3429 - val_loss: 1.1077
# Epoch 14/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.4095 - loss: 1.0710 - val_accuracy: 0.4857 - val_loss: 1.1036
# Epoch 15/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.4032 - loss: 1.0708 - val_accuracy: 0.4000 - val_loss: 1.0939
# Epoch 16/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.4317 - loss: 1.0575 - val_accuracy: 0.4857 - val_loss: 1.0811
# Epoch 17/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.4667 - loss: 1.0341 - val_accuracy: 0.5429 - val_loss: 0.9769
# Epoch 18/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.4921 - loss: 1.0249 - val_accuracy: 0.6286 - val_loss: 0.9560
# Epoch 19/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.5143 - loss: 0.9047 - val_accuracy: 0.6000 - val_loss: 0.8963
# Epoch 20/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.5556 - loss: 0.8478 - val_accuracy: 0.4571 - val_loss: 0.9923
# Epoch 21/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.5683 - loss: 0.8157 - val_accuracy: 0.6286 - val_loss: 0.8148
# Epoch 22/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.5651 - loss: 0.8025 - val_accuracy: 0.6571 - val_loss: 0.8371
# Epoch 23/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.6222 - loss: 0.7692 - val_accuracy: 0.5429 - val_loss: 0.8042
# Epoch 24/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.5968 - loss: 0.7708 - val_accuracy: 0.5143 - val_loss: 0.7966
# Epoch 25/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.5873 - loss: 0.7421 - val_accuracy: 0.6571 - val_loss: 0.7227
# Epoch 26/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6540 - loss: 0.7047 - val_accuracy: 0.5429 - val_loss: 0.7557
# Epoch 27/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6159 - loss: 0.7287 - val_accuracy: 0.6000 - val_loss: 0.7587
# Epoch 28/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6032 - loss: 0.6735 - val_accuracy: 0.5143 - val_loss: 0.7896
# Epoch 29/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6381 - loss: 0.6494 - val_accuracy: 0.6857 - val_loss: 0.7486
# Epoch 30/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6381 - loss: 0.6473 - val_accuracy: 0.6571 - val_loss: 0.8138
# Epoch 31/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6540 - loss: 0.6307 - val_accuracy: 0.6571 - val_loss: 0.7601
# Epoch 32/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.7079 - loss: 0.6078 - val_accuracy: 0.6571 - val_loss: 0.7601
# Epoch 33/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6794 - loss: 0.6173 - val_accuracy: 0.6000 - val_loss: 0.8478
# Epoch 34/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6921 - loss: 0.5951 - val_accuracy: 0.5429 - val_loss: 0.8834
# Epoch 35/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6857 - loss: 0.5832 - val_accuracy: 0.6571 - val_loss: 0.7750
# pred: [ 8 15 12]
#
# [Fold 2]
# Epoch 1/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.3429 - loss: 1.1039 - val_accuracy: 0.3714 - val_loss: 1.0944
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.3778 - loss: 1.0954 - val_accuracy: 0.3714 - val_loss: 1.0932
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.3206 - loss: 1.0953 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3714 - loss: 1.0955 - val_accuracy: 0.3714 - val_loss: 1.0924
# Epoch 5/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3714 - loss: 1.0966 - val_accuracy: 0.3714 - val_loss: 1.0932
# Epoch 6/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.3714 - loss: 1.0948 - val_accuracy: 0.3714 - val_loss: 1.0926
# Epoch 7/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.3651 - loss: 1.0931 - val_accuracy: 0.3714 - val_loss: 1.0912
# Epoch 8/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6730 - loss: 0.5571 - val_accuracy: 0.7429 - val_loss: 0.7538
# Epoch 53/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.7492 - loss: 0.4796 - val_accuracy: 0.7429 - val_loss: 0.6062
# Epoch 54/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.7810 - loss: 0.4426 - val_accuracy: 0.7714 - val_loss: 0.9864
# Epoch 55/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.7714 - loss: 0.4466 - val_accuracy: 0.7714 - val_loss: 0.6990
# Epoch 56/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.7651 - loss: 0.4571 - val_accuracy: 0.7714 - val_loss: 0.5281
# Epoch 57/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.7683 - loss: 0.4506 - val_accuracy: 0.7429 - val_loss: 0.7978
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b54c110a980> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b54c110a980> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# pred: [ 3 20 12]
#
# [Fold 4]
# Epoch 1/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.3651 - loss: 1.1006 - val_accuracy: 0.3429 - val_loss: 1.0946
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.3429 - loss: 1.0966 - val_accuracy: 0.3714 - val_loss: 1.0925
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3714 - loss: 1.0968 - val_accuracy: 0.3714 - val_loss: 1.0941
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3651 - loss: 1.0973 - val_accuracy: 0.3714 - val_loss: 1.0935
# Epoch 5/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3714 - loss: 1.0950 - val_accuracy: 0.3714 - val_loss: 1.0924
# Epoch 6/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3619 - loss: 1.0983 - val_accuracy: 0.3714 - val_loss: 1.0927
# Epoch 7/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3587 - loss: 1.0967 - val_accuracy: 0.3429 - val_loss: 1.0945
# Epoch 8/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.3365 - loss: 1.0947 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 9/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.3683 - loss: 1.0945 - val_accuracy: 0.3714 - val_loss: 1.0924
# Epoch 10/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3714 - loss: 1.0944 - val_accuracy: 0.3714 - val_loss: 1.0913
# Epoch 11/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.3714 - loss: 1.0933 - val_accuracy: 0.3714 - val_loss: 1.0904
# Epoch 12/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.3905 - loss: 1.0936 - val_accuracy: 0.4286 - val_loss: 1.0837
# Epoch 13/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3460 - loss: 1.0898 - val_accuracy: 0.3714 - val_loss: 1.0911
# Epoch 14/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.3746 - loss: 1.0953 - val_accuracy: 0.3714 - val_loss: 1.0866
# Epoch 15/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3873 - loss: 1.0839 - val_accuracy: 0.3714 - val_loss: 1.0733
# Epoch 16/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.8921 - loss: 0.2829 - val_accuracy: 0.8000 - val_loss: 0.4054
# Epoch 65/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9206 - loss: 0.2251 - val_accuracy: 0.7714 - val_loss: 0.4986
# Epoch 66/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.9365 - loss: 0.1796 - val_accuracy: 0.8286 - val_loss: 0.5126
# Epoch 67/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9333 - loss: 0.1591 - val_accuracy: 0.8571 - val_loss: 0.4327
# pred: [12 11 12]
#
# [Fold 6]
# Epoch 1/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.3175 - loss: 1.1039 - val_accuracy: 0.3429 - val_loss: 1.0939
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3746 - loss: 1.0958 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.3714 - loss: 1.0944 - val_accuracy: 0.3714 - val_loss: 1.0930
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.3746 - loss: 1.0961 - val_accuracy: 0.3714 - val_loss: 1.0934
# Epoch 5/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.3714 - loss: 1.0935 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 6/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.3714 - loss: 1.0960 - val_accuracy: 0.3714 - val_loss: 1.0926
# Epoch 7/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.3714 - loss: 1.0942 - val_accuracy: 0.3714 - val_loss: 1.0927
# Epoch 8/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.3746 - loss: 1.0950 - val_accuracy: 0.3714 - val_loss: 1.0925
# Epoch 9/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3746 - loss: 1.0928 - val_accuracy: 0.3714 - val_loss: 1.0913
# Epoch 10/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3683 - loss: 1.0928 - val_accuracy: 0.3714 - val_loss: 1.0870
# Epoch 11/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.3810 - loss: 1.0915 - val_accuracy: 0.4000 - val_loss: 1.0717
# Epoch 12/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.3746 - loss: 1.0928 - val_accuracy: 0.4000 - val_loss: 1.0813
# Epoch 13/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3778 - loss: 1.0782 - val_accuracy: 0.4286 - val_loss: 1.0627
# Epoch 14/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.4095 - loss: 1.0676 - val_accuracy: 0.4000 - val_loss: 1.0523
# Epoch 15/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.4254 - loss: 1.0589 - val_accuracy: 0.4286 - val_loss: 1.0695
# Epoch 16/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.3968 - loss: 1.0638 - val_accuracy: 0.4571 - val_loss: 1.0700
# Epoch 17/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.4159 - loss: 1.0374 - val_accuracy: 0.3714 - val_loss: 1.0305
# Epoch 18/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.3714 - loss: 1.0573 - val_accuracy: 0.4286 - val_loss: 1.0254
# Epoch 19/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.4254 - loss: 1.0322 - val_accuracy: 0.4000 - val_loss: 0.9864
# Epoch 20/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.4476 - loss: 1.0239 - val_accuracy: 0.4857 - val_loss: 1.0143
# Epoch 21/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.4381 - loss: 1.0202 - val_accuracy: 0.4571 - val_loss: 0.9402
# Epoch 22/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.4952 - loss: 0.9864 - val_accuracy: 0.5143 - val_loss: 0.9009
# Epoch 23/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.5111 - loss: 0.9830 - val_accuracy: 0.3714 - val_loss: 1.0377
# Epoch 24/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.5175 - loss: 0.9859 - val_accuracy: 0.5714 - val_loss: 0.8715
# Epoch 25/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5048 - loss: 0.9183 - val_accuracy: 0.6000 - val_loss: 0.8071
# Epoch 26/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.5492 - loss: 0.8717 - val_accuracy: 0.6286 - val_loss: 0.7371
# Epoch 27/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.5810 - loss: 0.8251 - val_accuracy: 0.5714 - val_loss: 0.7505
# Epoch 28/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.5905 - loss: 0.8269 - val_accuracy: 0.6571 - val_loss: 0.6740
# Epoch 29/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6317 - loss: 0.7135 - val_accuracy: 0.6286 - val_loss: 0.6163
# Epoch 30/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.5905 - loss: 0.7137 - val_accuracy: 0.6857 - val_loss: 0.6325
# Epoch 31/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6032 - loss: 0.6798 - val_accuracy: 0.6571 - val_loss: 0.6298
# Epoch 32/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.6317 - loss: 0.6522 - val_accuracy: 0.6571 - val_loss: 0.6173
# Epoch 33/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.6413 - loss: 0.6445 - val_accuracy: 0.6286 - val_loss: 0.7450
# Epoch 34/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6159 - loss: 0.6749 - val_accuracy: 0.6286 - val_loss: 0.6599
# Epoch 35/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6730 - loss: 0.6148 - val_accuracy: 0.6857 - val_loss: 0.6946
# Epoch 36/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.6603 - loss: 0.5925 - val_accuracy: 0.6286 - val_loss: 0.7375
# Epoch 37/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6571 - loss: 0.6355 - val_accuracy: 0.6571 - val_loss: 0.7941
# Epoch 38/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6381 - loss: 0.5954 - val_accuracy: 0.6571 - val_loss: 0.6519
# Epoch 39/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6825 - loss: 0.5884 - val_accuracy: 0.6286 - val_loss: 0.7247
# pred: [ 2 20 13]
#
# [Fold 7]
# Epoch 1/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.3206 - loss: 1.1034 - val_accuracy: 0.3714 - val_loss: 1.0953
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.3651 - loss: 1.0950 - val_accuracy: 0.3714 - val_loss: 1.0932
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.3714 - loss: 1.0952 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.6730 - loss: 0.5670 - val_accuracy: 0.5143 - val_loss: 1.0217
# Epoch 28/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6857 - loss: 0.6177 - val_accuracy: 0.6286 - val_loss: 0.8835
# Epoch 29/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6794 - loss: 0.5600 - val_accuracy: 0.6286 - val_loss: 0.7004
# Epoch 30/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.6857 - loss: 0.5642 - val_accuracy: 0.6000 - val_loss: 0.7619
# Epoch 31/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.7302 - loss: 0.5304 - val_accuracy: 0.6000 - val_loss: 0.7051
# Epoch 32/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.7619 - loss: 0.4999 - val_accuracy: 0.6571 - val_loss: 0.7121
# Epoch 33/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.7619 - loss: 0.4765 - val_accuracy: 0.6286 - val_loss: 0.6927
# Epoch 34/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.8032 - loss: 0.4444 - val_accuracy: 0.7429 - val_loss: 0.8406
# Epoch 35/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7492 - loss: 0.4731 - val_accuracy: 0.6571 - val_loss: 0.7672
# Epoch 36/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.8286 - loss: 0.4051 - val_accuracy: 0.6857 - val_loss: 0.7170
# Epoch 37/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.8095 - loss: 0.4084 - val_accuracy: 0.6286 - val_loss: 1.0670
# Epoch 38/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.8000 - loss: 0.4339 - val_accuracy: 0.6857 - val_loss: 0.6998
# Epoch 39/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8349 - loss: 0.4245 - val_accuracy: 0.6000 - val_loss: 0.8403
# Epoch 40/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8127 - loss: 0.4208 - val_accuracy: 0.6857 - val_loss: 0.7411
# Epoch 41/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8540 - loss: 0.3528 - val_accuracy: 0.7714 - val_loss: 0.7065
# Epoch 42/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9079 - loss: 0.3030 - val_accuracy: 0.6000 - val_loss: 0.9514
# Epoch 43/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8540 - loss: 0.3634 - val_accuracy: 0.6857 - val_loss: 0.8784
# pred: [10 16  9]
#
# [Fold 8]
# Epoch 1/80
# ...
# Epoch 16/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.3651 - loss: 1.0939 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 17/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.3714 - loss: 1.0954 - val_accuracy: 0.3714 - val_loss: 1.0931
# Epoch 18/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3333 - loss: 1.0950 - val_accuracy: 0.3714 - val_loss: 1.0932
# pred: [ 0 35  0]
#
# [Fold 8]
# Epoch 1/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.3270 - loss: 1.1031 - val_accuracy: 0.3429 - val_loss: 1.0975
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3333 - loss: 1.0982 - val_accuracy: 0.3714 - val_loss: 1.0934
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3333 - loss: 1.0955 - val_accuracy: 0.3714 - val_loss: 1.0937
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3175 - loss: 1.0947 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 5/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.3714 - loss: 1.0955 - val_accuracy: 0.3714 - val_loss: 1.0931
# Epoch 6/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.3746 - loss: 1.0943 - val_accuracy: 0.3429 - val_loss: 1.0915
# Epoch 7/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.3397 - loss: 1.0969 - val_accuracy: 0.3714 - val_loss: 1.0914
# Epoch 8/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.3587 - loss: 1.0932 - val_accuracy: 0.4571 - val_loss: 1.0856
# Epoch 9/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.3873 - loss: 1.0858 - val_accuracy: 0.4000 - val_loss: 1.0423
# Epoch 10/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4095 - loss: 1.0931 - val_accuracy: 0.3429 - val_loss: 1.0832
# Epoch 11/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.3905 - loss: 1.0819 - val_accuracy: 0.4571 - val_loss: 1.0534
# Epoch 12/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.4540 - loss: 1.0435 - val_accuracy: 0.6000 - val_loss: 0.8617
# Epoch 13/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.5746 - loss: 0.8688 - val_accuracy: 0.5143 - val_loss: 0.8274
# Epoch 14/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.5714 - loss: 0.7752 - val_accuracy: 0.4857 - val_loss: 0.9295
# Epoch 15/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6032 - loss: 0.7567 - val_accuracy: 0.6000 - val_loss: 0.7449
# Epoch 16/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6032 - loss: 0.7240 - val_accuracy: 0.5143 - val_loss: 0.8523
# Epoch 17/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6063 - loss: 0.7173 - val_accuracy: 0.5429 - val_loss: 0.8113
# Epoch 18/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6317 - loss: 0.6659 - val_accuracy: 0.5143 - val_loss: 0.7804
# Epoch 19/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6222 - loss: 0.6368 - val_accuracy: 0.5429 - val_loss: 0.8756
# Epoch 20/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6349 - loss: 0.6553 - val_accuracy: 0.5429 - val_loss: 0.7940
# Epoch 21/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6667 - loss: 0.6211 - val_accuracy: 0.6571 - val_loss: 0.7092
# Epoch 22/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6603 - loss: 0.6065 - val_accuracy: 0.5714 - val_loss: 0.9404
# Epoch 23/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6667 - loss: 0.5894 - val_accuracy: 0.5143 - val_loss: 0.7503
# Epoch 24/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6381 - loss: 0.6053 - val_accuracy: 0.5714 - val_loss: 0.8252
# Epoch 25/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6635 - loss: 0.5879 - val_accuracy: 0.4857 - val_loss: 0.8546
# Epoch 26/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6635 - loss: 0.5673 - val_accuracy: 0.5143 - val_loss: 1.0017
# Epoch 27/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6444 - loss: 0.5941 - val_accuracy: 0.6571 - val_loss: 0.6632
# Epoch 28/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6444 - loss: 0.6098 - val_accuracy: 0.5714 - val_loss: 1.0197
# Epoch 29/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6349 - loss: 0.5972 - val_accuracy: 0.6000 - val_loss: 0.7683
# Epoch 30/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6603 - loss: 0.5812 - val_accuracy: 0.6571 - val_loss: 0.7942
# Epoch 31/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.6762 - loss: 0.5761 - val_accuracy: 0.5714 - val_loss: 1.0774
# Epoch 32/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6667 - loss: 0.5526 - val_accuracy: 0.5714 - val_loss: 1.0703
# Epoch 33/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.6698 - loss: 0.5669 - val_accuracy: 0.6000 - val_loss: 0.7300
# Epoch 34/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6921 - loss: 0.5335 - val_accuracy: 0.6286 - val_loss: 0.8551
# Epoch 35/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.6603 - loss: 0.5798 - val_accuracy: 0.5714 - val_loss: 0.8272
# Epoch 36/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6381 - loss: 0.5703 - val_accuracy: 0.6000 - val_loss: 0.7681
# Epoch 37/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.6635 - loss: 0.5350 - val_accuracy: 0.6000 - val_loss: 0.8482
# pred: [ 2 21 12]
#
# [Fold 9]
# Epoch 1/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.3714 - loss: 1.1033 - val_accuracy: 0.3714 - val_loss: 1.0945
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.3746 - loss: 1.0996 - val_accuracy: 0.3714 - val_loss: 1.0941
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.3714 - loss: 1.0941 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.3460 - loss: 1.0962 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 5/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.3714 - loss: 1.0961 - val_accuracy: 0.3714 - val_loss: 1.0930
# Epoch 6/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.3556 - loss: 1.0957 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 7/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.3714 - loss: 1.0935 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 8/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.3714 - loss: 1.0967 - val_accuracy: 0.3714 - val_loss: 1.0933
# Epoch 9/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.3714 - loss: 1.0951 - val_accuracy: 0.3714 - val_loss: 1.0930
# Epoch 10/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.3714 - loss: 1.0966 - val_accuracy: 0.3714 - val_loss: 1.0930
# Epoch 11/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.3651 - loss: 1.0983 - val_accuracy: 0.3714 - val_loss: 1.0932
# Epoch 12/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.3365 - loss: 1.0959 - val_accuracy: 0.3714 - val_loss: 1.0930
# Epoch 13/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.3810 - loss: 1.0934 - val_accuracy: 0.3714 - val_loss: 1.0926
# Epoch 14/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.3714 - loss: 1.0936 - val_accuracy: 0.3714 - val_loss: 1.0926
# Epoch 15/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.3714 - loss: 1.0924 - val_accuracy: 0.3714 - val_loss: 1.0903
# Epoch 16/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.3524 - loss: 1.0877 - val_accuracy: 0.3714 - val_loss: 1.0812
# Epoch 17/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.4159 - loss: 1.0647 - val_accuracy: 0.5429 - val_loss: 0.9199
# Epoch 18/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.5651 - loss: 0.9022 - val_accuracy: 0.6286 - val_loss: 0.7265
# Epoch 19/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.5651 - loss: 0.8837 - val_accuracy: 0.6000 - val_loss: 0.7455
# Epoch 20/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5778 - loss: 0.8424 - val_accuracy: 0.6571 - val_loss: 0.7220
# Epoch 21/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6095 - loss: 0.8091 - val_accuracy: 0.6571 - val_loss: 0.7177
# Epoch 22/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.5746 - loss: 0.7616 - val_accuracy: 0.5429 - val_loss: 0.7291
# Epoch 23/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.5810 - loss: 0.7909 - val_accuracy: 0.6286 - val_loss: 0.7265
# Epoch 24/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.5905 - loss: 0.7889 - val_accuracy: 0.6571 - val_loss: 0.7145
# Epoch 25/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6222 - loss: 0.7463 - val_accuracy: 0.6571 - val_loss: 0.6821
# Epoch 26/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6254 - loss: 0.7085 - val_accuracy: 0.5714 - val_loss: 0.7909
# Epoch 27/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6254 - loss: 0.7236 - val_accuracy: 0.6857 - val_loss: 0.6135
# Epoch 28/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6349 - loss: 0.6948 - val_accuracy: 0.6857 - val_loss: 0.6205
# Epoch 29/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.6254 - loss: 0.6854 - val_accuracy: 0.6571 - val_loss: 0.6913
# Epoch 30/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6508 - loss: 0.6572 - val_accuracy: 0.6571 - val_loss: 0.6368
# Epoch 31/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6698 - loss: 0.6244 - val_accuracy: 0.7143 - val_loss: 0.6943
# Epoch 32/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.6571 - loss: 0.6527 - val_accuracy: 0.5714 - val_loss: 0.6668
# Epoch 33/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6444 - loss: 0.6354 - val_accuracy: 0.7429 - val_loss: 0.6478
# Epoch 34/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.6413 - loss: 0.6688 - val_accuracy: 0.7143 - val_loss: 0.6282
# Epoch 35/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.6984 - loss: 0.6266 - val_accuracy: 0.6857 - val_loss: 0.7063
# Epoch 36/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6698 - loss: 0.6102 - val_accuracy: 0.6571 - val_loss: 0.7627
# Epoch 37/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.6889 - loss: 0.6094 - val_accuracy: 0.6571 - val_loss: 0.6401
# pred: [ 0 21 14]
#
# [Fold 10]
# Epoch 1/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.3524 - loss: 1.0995 - val_accuracy: 0.3429 - val_loss: 1.0949
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.3429 - loss: 1.0966 - val_accuracy: 0.3714 - val_loss: 1.0937
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.3714 - loss: 1.0961 - val_accuracy: 0.3714 - val_loss: 1.0931
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.3619 - loss: 1.0970 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 5/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3873 - loss: 1.0948 - val_accuracy: 0.3714 - val_loss: 1.0930
# Epoch 6/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.3714 - loss: 1.0971 - val_accuracy: 0.3714 - val_loss: 1.0934
# Epoch 7/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.3492 - loss: 1.0940 - val_accuracy: 0.3714 - val_loss: 1.0932
# Epoch 8/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.3429 - loss: 1.0963 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 9/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.3492 - loss: 1.0934 - val_accuracy: 0.3143 - val_loss: 1.0945
# Epoch 10/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.3714 - loss: 1.0916 - val_accuracy: 0.3143 - val_loss: 1.1103
# Epoch 11/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.3968 - loss: 1.0845 - val_accuracy: 0.3429 - val_loss: 1.1158
# Epoch 12/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.4000 - loss: 1.0712 - val_accuracy: 0.4286 - val_loss: 1.1266
# Epoch 13/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.4476 - loss: 1.0524 - val_accuracy: 0.3714 - val_loss: 1.0901
# Epoch 14/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.4889 - loss: 1.0116 - val_accuracy: 0.4571 - val_loss: 1.1031
# Epoch 15/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.5937 - loss: 0.9122 - val_accuracy: 0.4857 - val_loss: 1.0416
# Epoch 16/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.5968 - loss: 0.8065 - val_accuracy: 0.4857 - val_loss: 0.9344
# Epoch 17/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.6286 - loss: 0.7362 - val_accuracy: 0.6000 - val_loss: 0.9520
# Epoch 18/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.6095 - loss: 0.7581 - val_accuracy: 0.5429 - val_loss: 0.9628
# Epoch 19/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.6254 - loss: 0.6751 - val_accuracy: 0.5143 - val_loss: 0.9282
# Epoch 20/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.6159 - loss: 0.6794 - val_accuracy: 0.5429 - val_loss: 0.8929
# Epoch 21/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6476 - loss: 0.6697 - val_accuracy: 0.4571 - val_loss: 0.9868
# Epoch 22/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6286 - loss: 0.7065 - val_accuracy: 0.5714 - val_loss: 0.8808
# Epoch 23/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6444 - loss: 0.6279 - val_accuracy: 0.6000 - val_loss: 0.9254
# Epoch 24/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6667 - loss: 0.5943 - val_accuracy: 0.5143 - val_loss: 1.0023
# Epoch 25/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.6508 - loss: 0.6038 - val_accuracy: 0.5714 - val_loss: 1.0173
# Epoch 26/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.6063 - loss: 0.6304 - val_accuracy: 0.5714 - val_loss: 0.9736
# Epoch 27/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6254 - loss: 0.6275 - val_accuracy: 0.6000 - val_loss: 0.8628
# Epoch 28/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.6286 - loss: 0.6008 - val_accuracy: 0.5714 - val_loss: 1.0226
# Epoch 29/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6762 - loss: 0.5708 - val_accuracy: 0.5714 - val_loss: 1.0017
# Epoch 30/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.6889 - loss: 0.5501 - val_accuracy: 0.6000 - val_loss: 1.0686
# Epoch 31/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.7175 - loss: 0.5446 - val_accuracy: 0.5714 - val_loss: 1.1392
# Epoch 32/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6698 - loss: 0.5744 - val_accuracy: 0.5429 - val_loss: 1.2458
# Epoch 33/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6571 - loss: 0.6091 - val_accuracy: 0.5429 - val_loss: 0.8518
# Epoch 34/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6667 - loss: 0.5911 - val_accuracy: 0.5429 - val_loss: 1.0632
# Epoch 35/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6889 - loss: 0.5312 - val_accuracy: 0.5714 - val_loss: 1.0260
# Epoch 36/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.6952 - loss: 0.5237 - val_accuracy: 0.5714 - val_loss: 1.0983
# Epoch 37/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.7238 - loss: 0.4766 - val_accuracy: 0.5429 - val_loss: 1.2628
# Epoch 38/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.7460 - loss: 0.5092 - val_accuracy: 0.5714 - val_loss: 1.2803
# Epoch 39/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.7587 - loss: 0.4786 - val_accuracy: 0.7143 - val_loss: 0.9637
# Epoch 40/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.7206 - loss: 0.5205 - val_accuracy: 0.5429 - val_loss: 1.1192
# Epoch 41/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.7810 - loss: 0.4406 - val_accuracy: 0.5714 - val_loss: 1.2898
# Epoch 42/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.8095 - loss: 0.4145 - val_accuracy: 0.7429 - val_loss: 1.2519
# Epoch 43/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.7746 - loss: 0.4605 - val_accuracy: 0.6571 - val_loss: 1.4917
# pred: [ 1 27  7]
# Model with conv_filters=32 and lstm_units=128 saved as 'violence_detection_model_conv_32_lstm_128.h5'
# Average F1-Score: 0.5636
# Average AUC: 0.8808
#
# [Fold 1]
# Epoch 1/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.3270 - loss: 1.1042 - val_accuracy: 0.3714 - val_loss: 1.0941
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.3524 - loss: 1.0944 - val_accuracy: 0.3714 - val_loss: 1.0930
# Epoch 3/80
#  7/40 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.3707 - loss: 1.1078

# %% [markdown]
# ### 4. Plot the results

# %%
import numpy as np
import matplotlib.pyplot as plt

# Get the length of the longest history record
max_len = max([len(history['loss']) for key in results_neurons for history in results_neurons[key]['histories']])

# Define a function to pad history records
def pad_history(history, max_len):
    padded_history = {}
    for key in history:
        padded_history[key] = history[key] + [history[key][-1]] * (max_len - len(history[key]))
    return padded_history

# Pad all history records
padded_results_neurons = {}
for key in results_neurons:
    padded_histories = [pad_history(history, max_len) for history in results_neurons[key]['histories']]
    padded_results_neurons[key] = {
        'histories': padded_histories,
        'mean_fpr': results_neurons[key]['mean_fpr'],
        'mean_tpr': results_neurons[key]['mean_tpr'],
        'mean_auc_curve': results_neurons[key]['mean_auc_curve']
    }

# Plot training loss
plt.figure(figsize=(12, 6))
for key in padded_results_neurons:
    mean_loss = np.mean([history['loss'] for history in padded_results_neurons[key]['histories']], axis=0)
    plt.plot(mean_loss, label=f'Training {key}')
plt.title('Training Loss for Different Configurations')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot validation loss
plt.figure(figsize=(12, 6))
for key in padded_results_neurons:
    mean_val_loss = np.mean([history['val_loss'] for history in padded_results_neurons[key]['histories']], axis=0)
    plt.plot(mean_val_loss, label=f'Validation {key}')
plt.title('Validation Loss for Different Configurations')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training accuracy
plt.figure(figsize=(12, 6))
for key in padded_results_neurons:
    mean_accuracy = np.mean([history['accuracy'] for history in padded_results_neurons[key]['histories']], axis=0)
    plt.plot(mean_accuracy, label=f'Training {key}')
plt.title('Training Accuracy for Different Configurations')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot validation accuracy
plt.figure(figsize=(12, 6))
for key in padded_results_neurons:
    mean_val_accuracy = np.mean([history['val_accuracy'] for history in padded_results_neurons[key]['histories']], axis=0)
    plt.plot(mean_val_accuracy, label=f'Validation {key}')
plt.title('Validation Accuracy for Different Configurations')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot ROC curve
plt.figure(figsize=(12, 6))
for key in padded_results_neurons:
    mean_fpr = padded_results_neurons[key]['mean_fpr']
    mean_tpr = padded_results_neurons[key]['mean_tpr']
    mean_auc = padded_results_neurons[key]['mean_auc_curve']
    plt.plot(mean_fpr, mean_tpr, label=f'{key} (AUC = {mean_auc:.2f})')

plt.plot([0, 1], [0, 1], color='r', linestyle='--')
plt.title('Receiver Operating Characteristic (ROC)')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.show()

# %%
save_dir = BASE_DIR / "train_weight"
save_dir.mkdir(parents=True, exist_ok=True)

conv_filters=64
lstm_units=64

model = create_model(input_shape, num_classes, conv_filters, lstm_units)
model.fit(data, targets, epochs=25, batch_size=8)
model.save(save_dir / f'violence_detection_model_conv_{conv_filters}_lstm_{lstm_units}_revisedv1.h5')
print(f"Model with conv_filters={conv_filters} and lstm_units={lstm_units} saved.")
