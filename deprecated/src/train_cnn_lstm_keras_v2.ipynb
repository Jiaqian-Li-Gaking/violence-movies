# %% [markdown]
# ### Change 3dcnnlstm to 2dcnnlstm

# %% [markdown]
# ### 1. Load data

# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)

gpus = tf.config.list_physical_devices('GPU')
print("GPUs:", gpus)
# Out:
# 2026-01-27 10:37:05.433939: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-27 10:37:06.445417: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-27 10:37:24.515755: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# /mnt/d/Myworkplace/Python/violence-movies/.venv/lib/python3.12/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# TensorFlow version: 2.20.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D,
    TimeDistributed, GlobalAveragePooling2D,
    LSTM, Dropout, Dense
)
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, roc_curve, auc, roc_auc_score
from pathlib import Path
import gc

try:
    BASE_DIR = Path(__file__).resolve().parent.parent
except NameError:
    # Jupyter notebook fallback
    BASE_DIR = Path.cwd().parent

def load_data(folders, labels, base_path, frame_count=10):
    data = []
    targets = []
    for folder in folders:
        folder_path = os.path.join(base_path, folder)
        for video_folder in os.listdir(folder_path):
            video_path = os.path.join(folder_path, video_folder)
            frames = []
            for frame_file in sorted(os.listdir(video_path))[:frame_count]:
                frame_path = os.path.join(video_path, frame_file)
                frame = cv2.imread(frame_path)
                frame = cv2.resize(frame, (112, 112))
                frames.append(frame)

            # for i, frame in enumerate(frames):
            #     cv2.imshow("Resized Frame (64x64)", frame)
            #     key = cv2.waitKey(0)
            #     if key == 27:  # ESC
            #         cv2.destroyAllWindows()
            #         return None, None  # stop after first video
            # cv2.destroyAllWindows()

            if len(frames) < frame_count:
                frames.extend([np.zeros_like(frames[0])]*(frame_count - len(frames)))
            data.append(frames)
            targets.append(labels[folder])
    return np.array(data), np.array(targets)

base_path = BASE_DIR / "data" / "processed" / "violence-detection-dataset"
folders = ["high-level violence_frames", "low-level violence_frames", "non-violence_frames"]
labels = {"high-level violence_frames": 0, "low-level violence_frames": 1, "non-violence_frames": 2}

data, targets = load_data(folders, labels, base_path)
data = data / 255.0

print(f"Data shape: {data.shape}")
print(f"Targets shape: {targets.shape}")
# Out:
# Data shape: (350, 10, 112, 112, 3)
# Targets shape: (350,)

# %% [markdown]
# ### 2. Create model

# %%
# change maxpooling3D from (2,2,2) to (1,2,2)
def create_model(input_shape, num_classes, conv_filters, lstm_units, dropout_rate=0.5):
    # (batch, 10, 64, 64, 3)
    inputs = Input(shape=input_shape)    

    # -------- Block 1 --------
    # (batch, 10, 112, 112, conv_filters)
    x = TimeDistributed(
        Conv2D(conv_filters, (3, 3), activation="relu", padding="same")
    )(inputs)
    # (batch, 10, 56, 56, conv_filters)
    x = TimeDistributed(MaxPooling2D((2, 2)))(x)

    # -------- Block 2 --------
    # (batch, 10, 56, 56, conv_filters)
    x = TimeDistributed(
        Conv2D(conv_filters, (3, 3), activation="relu", padding="same")
    )(x)
    # (batch, 10, 28, 28, conv_filters)
    x = TimeDistributed(MaxPooling2D((2, 2)))(x)

    # -------- Block 3 --------
    # (batch, 10, 28, 28, conv_filters)
    x = TimeDistributed(
        Conv2D(conv_filters, (3, 3), activation="relu", padding="same")
    )(x)
    # (batch, 10, 14, 14, conv_filters)
    x = TimeDistributed(MaxPooling2D((2, 2)))(x)

    # -------- Spatial compression --------
    # (batch, 10, conv_filters)
    x = TimeDistributed(GlobalAveragePooling2D())(x)

    # -------- Temporal modeling --------
    # (batch, lstm_units)
    x = LSTM(lstm_units)(x)
    x = Dropout(dropout_rate)(x)

    # -------- Classification head --------
    # (batch, 256)
    x = Dense(256, activation='relu')(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs, outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    return model

input_shape = (10, 112, 112, 3)
num_classes = 3
# conv_filters_list = [32, 64, 128]
# lstm_units_list = [64, 128]
conv_filters_list = [64]
lstm_units_list = [64]
# conv_filters_list = [128]
# lstm_units_list = [128]
dropout_rate_list = [0.2,0.3,0.4,0.5]
results_neurons = {}

# early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
mean_fpr = np.linspace(0, 1, 100)

# %% [markdown]
# ### 3. Train

# %%
for conv_filters in conv_filters_list:
    for lstm_units in lstm_units_list:
        f1_scores = []
        roc_aucs = []
        tprs = []
        histories = []

        for fold, (train_index, val_index) in enumerate(kf.split(data, targets), start=1):
        # for train_index, val_index in kf.split(data, targets):
            X_train, X_val = data[train_index], data[val_index]
            y_train, y_val = targets[train_index], targets[val_index]

            print(f"\n[Fold {fold}]")

            early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
            model = create_model(input_shape, num_classes, conv_filters, lstm_units)
            history = model.fit(X_train, y_train, validation_data=(X_val, y_val), 
                                epochs=80, batch_size=8, callbacks=[early_stopping])
            histories.append(history.history)

            y_val_pred = model.predict(X_val, batch_size=8, verbose=0)
            y_val_pred_classes = np.argmax(y_val_pred, axis=1)

            print("pred:", np.bincount(y_val_pred_classes, minlength=num_classes))

            f1 = f1_score(y_val, y_val_pred_classes, average='weighted')
            f1_scores.append(f1)

            fpr, tpr, _ = roc_curve(y_val, y_val_pred_classes, pos_label=2)
            roc_auc = auc(fpr, tpr)
            roc_aucs.append(roc_auc)
            tprs.append(np.interp(mean_fpr, fpr, tpr))
            tprs[-1][0] = 0.0

            # discard fold model
            K.clear_session()
            del model
            gc.collect()

        mean_tpr = np.mean(tprs, axis=0)
        mean_tpr[-1] = 1.0
        mean_auc = auc(mean_fpr, mean_tpr)

        results_neurons[f'conv_filters_{conv_filters}_lstm_units_{lstm_units}'] = {
            'histories': histories,
            'mean_f1_score': np.mean(f1_scores),
            'mean_auc': np.mean(roc_aucs),
            'mean_tpr': mean_tpr,
            'mean_fpr': mean_fpr,
            'mean_auc_curve': mean_auc
        }


        print(f"Model with conv_filters={conv_filters} and lstm_units={lstm_units} saved.")
        print(f"Average F1-Score: {np.mean(f1_scores):.4f}")
        print(f"Average AUC: {np.mean(roc_aucs):.4f}")
# Out:
# [Fold 1]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1769481556.241091     721 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5520 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/80
# 2026-01-27 10:39:20.557623: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 129ms/step - accuracy: 0.3238 - loss: 1.1062 - val_accuracy: 0.3714 - val_loss: 1.0975
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3683 - loss: 1.0976 - val_accuracy: 0.3714 - val_loss: 1.0946
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3683 - loss: 1.0944 - val_accuracy: 0.3714 - val_loss: 1.0927
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3492 - loss: 1.0934 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 5/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.3651 - loss: 1.0946 - val_accuracy: 0.3714 - val_loss: 1.0925
# Epoch 6/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.3460 - loss: 1.0982 - val_accuracy: 0.3714 - val_loss: 1.0931
# Epoch 7/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - accuracy: 0.3746 - loss: 1.0940 - val_accuracy: 0.4571 - val_loss: 1.0918
# Epoch 8/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.3746 - loss: 1.0924 - val_accuracy: 0.3714 - val_loss: 1.0914
# Epoch 9/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.4000 - loss: 1.0929 - val_accuracy: 0.3714 - val_loss: 1.0932
# Epoch 10/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.3841 - loss: 1.0939 - val_accuracy: 0.4000 - val_loss: 1.0885
# Epoch 11/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.4381 - loss: 1.0786 - val_accuracy: 0.4286 - val_loss: 1.0600
# Epoch 12/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.4825 - loss: 1.0534 - val_accuracy: 0.4857 - val_loss: 1.0440
# Epoch 13/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.4889 - loss: 0.9948 - val_accuracy: 0.5429 - val_loss: 0.9449
# Epoch 14/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - accuracy: 0.5746 - loss: 0.9227 - val_accuracy: 0.5429 - val_loss: 0.9394
# Epoch 15/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.5746 - loss: 0.8348 - val_accuracy: 0.6000 - val_loss: 0.8789
# Epoch 16/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.3683 - loss: 1.0980 - val_accuracy: 0.3714 - val_loss: 1.0931
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3619 - loss: 1.0959 - val_accuracy: 0.3714 - val_loss: 1.0930
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.3524 - loss: 1.0946 - val_accuracy: 0.3714 - val_loss: 1.0926
# Epoch 5/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.3714 - loss: 1.0967 - val_accuracy: 0.3714 - val_loss: 1.0931
# Epoch 6/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.3556 - loss: 1.0955 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 7/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - accuracy: 0.3714 - loss: 1.0953 - val_accuracy: 0.3714 - val_loss: 1.0924
# Epoch 8/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.3714 - loss: 1.0935 - val_accuracy: 0.3714 - val_loss: 1.0927
# Epoch 9/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.3651 - loss: 1.0952 - val_accuracy: 0.3714 - val_loss: 1.0926
# Epoch 10/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3714 - loss: 1.0959 - val_accuracy: 0.3714 - val_loss: 1.0916
# Epoch 11/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.3746 - loss: 1.0937 - val_accuracy: 0.3714 - val_loss: 1.0927
# Epoch 12/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3587 - loss: 1.0976 - val_accuracy: 0.3714 - val_loss: 1.0927
# Epoch 13/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3714 - loss: 1.0947 - val_accuracy: 0.3714 - val_loss: 1.0924
# Epoch 14/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.3810 - loss: 1.1017 - val_accuracy: 0.3714 - val_loss: 1.0934
# Epoch 15/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - accuracy: 0.3714 - loss: 1.0935 - val_accuracy: 0.3714 - val_loss: 1.0930
# Epoch 16/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - accuracy: 0.3714 - loss: 1.0948 - val_accuracy: 0.3714 - val_loss: 1.0931
# Epoch 17/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3714 - loss: 1.0944 - val_accuracy: 0.3714 - val_loss: 1.0927
# Epoch 18/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.3714 - loss: 1.0949 - val_accuracy: 0.3714 - val_loss: 1.0921
# Epoch 19/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3841 - loss: 1.0927 - val_accuracy: 0.3714 - val_loss: 1.0887
# Epoch 20/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.4190 - loss: 1.0826 - val_accuracy: 0.5429 - val_loss: 1.0612
# Epoch 21/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.4984 - loss: 1.0335 - val_accuracy: 0.5143 - val_loss: 0.9626
# Epoch 22/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.5492 - loss: 0.9394 - val_accuracy: 0.5714 - val_loss: 0.9433
# Epoch 23/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.5492 - loss: 0.8442 - val_accuracy: 0.5714 - val_loss: 0.7775
# Epoch 24/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - accuracy: 0.6825 - loss: 0.5159 - val_accuracy: 0.4857 - val_loss: 1.3448
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f9461f13b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f9461f13b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# pred: [ 0 19 16]
#
# [Fold 4]
# Epoch 1/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.3492 - loss: 1.1001 - val_accuracy: 0.3714 - val_loss: 1.0955
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.3714 - loss: 1.0961 - val_accuracy: 0.3714 - val_loss: 1.0945
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.3270 - loss: 1.0968 - val_accuracy: 0.3714 - val_loss: 1.0931
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.3619 - loss: 1.0973 - val_accuracy: 0.3714 - val_loss: 1.0927
# Epoch 5/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.3714 - loss: 1.0940 - val_accuracy: 0.3714 - val_loss: 1.0916
# Epoch 6/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.3714 - loss: 1.0951 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 7/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.3714 - loss: 1.0929 - val_accuracy: 0.3714 - val_loss: 1.0925
# Epoch 8/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3714 - loss: 1.0939 - val_accuracy: 0.3714 - val_loss: 1.0917
# Epoch 9/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.4000 - loss: 1.0933 - val_accuracy: 0.3714 - val_loss: 1.0910
# Epoch 10/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.3683 - loss: 1.0957 - val_accuracy: 0.3714 - val_loss: 1.0920
# Epoch 11/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.3714 - loss: 1.0944 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 12/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.3587 - loss: 1.0943 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 13/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.3714 - loss: 1.0926 - val_accuracy: 0.3714 - val_loss: 1.0924
# Epoch 14/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.3175 - loss: 1.0962 - val_accuracy: 0.3714 - val_loss: 1.0911
# Epoch 15/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.3841 - loss: 1.0909 - val_accuracy: 0.3714 - val_loss: 1.0809
# Epoch 16/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3968 - loss: 1.0852 - val_accuracy: 0.4000 - val_loss: 1.0560
# Epoch 17/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.5048 - loss: 1.0048 - val_accuracy: 0.5429 - val_loss: 0.8588
# Epoch 18/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.5556 - loss: 0.9182 - val_accuracy: 0.6286 - val_loss: 0.7680
# Epoch 19/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.5746 - loss: 0.8531 - val_accuracy: 0.5714 - val_loss: 0.7468
# Epoch 20/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.6000 - loss: 0.8307 - val_accuracy: 0.6571 - val_loss: 0.6620
# Epoch 21/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.5810 - loss: 0.8284 - val_accuracy: 0.6286 - val_loss: 0.6468
# Epoch 22/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - accuracy: 0.5937 - loss: 0.7954 - val_accuracy: 0.6857 - val_loss: 0.7055
# Epoch 23/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.6032 - loss: 0.7510 - val_accuracy: 0.6571 - val_loss: 0.6513
# Epoch 24/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.6063 - loss: 0.7666 - val_accuracy: 0.6571 - val_loss: 0.6351
# Epoch 25/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.5937 - loss: 0.7643 - val_accuracy: 0.6000 - val_loss: 0.6612
# Epoch 26/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.5968 - loss: 0.7190 - val_accuracy: 0.6571 - val_loss: 0.6489
# Epoch 27/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.6286 - loss: 0.6950 - val_accuracy: 0.6857 - val_loss: 0.5952
# Epoch 28/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.6095 - loss: 0.7083 - val_accuracy: 0.6857 - val_loss: 0.6155
# Epoch 29/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - accuracy: 0.6286 - loss: 0.6876 - val_accuracy: 0.6571 - val_loss: 0.5974
# Epoch 30/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.6444 - loss: 0.6751 - val_accuracy: 0.5714 - val_loss: 0.5991
# Epoch 31/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.6825 - loss: 0.6678 - val_accuracy: 0.6857 - val_loss: 0.6267
# Epoch 32/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.6667 - loss: 0.6789 - val_accuracy: 0.5429 - val_loss: 0.6190
# Epoch 33/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.6254 - loss: 0.6871 - val_accuracy: 0.6000 - val_loss: 0.7787
# Epoch 34/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.6984 - loss: 0.6784 - val_accuracy: 0.5143 - val_loss: 0.6625
# Epoch 35/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.6794 - loss: 0.6601 - val_accuracy: 0.6571 - val_loss: 0.6711
# Epoch 36/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.7048 - loss: 0.6357 - val_accuracy: 0.5429 - val_loss: 0.6213
# Epoch 37/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step - accuracy: 0.6825 - loss: 0.6305 - val_accuracy: 0.5714 - val_loss: 0.6685
# pred: [ 0 24 11]
#
# [Fold 5]
# Epoch 1/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.2984 - loss: 1.1024 - val_accuracy: 0.3714 - val_loss: 1.0943
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.3714 - loss: 1.0953 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3714 - loss: 1.0956 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.3714 - loss: 1.0943 - val_accuracy: 0.3714 - val_loss: 1.0925
# Epoch 5/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3714 - loss: 1.0950 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 6/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - accuracy: 0.3778 - loss: 1.0971 - val_accuracy: 0.3714 - val_loss: 1.0938
# Epoch 7/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.3683 - loss: 1.0954 - val_accuracy: 0.3714 - val_loss: 1.0930
# Epoch 8/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.3619 - loss: 1.0948 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 9/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.3714 - loss: 1.0927 - val_accuracy: 0.3714 - val_loss: 1.0930
# Epoch 10/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.3714 - loss: 1.0968 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 11/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3714 - loss: 1.0942 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 12/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.3714 - loss: 1.0926 - val_accuracy: 0.3714 - val_loss: 1.0925
# Epoch 13/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - accuracy: 0.3714 - loss: 1.0948 - val_accuracy: 0.3714 - val_loss: 1.0921
# Epoch 14/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.3587 - loss: 1.0985 - val_accuracy: 0.3714 - val_loss: 1.0930
# Epoch 15/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.3714 - loss: 1.0967 - val_accuracy: 0.3714 - val_loss: 1.0931
# Epoch 16/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.3714 - loss: 1.0948 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 17/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3714 - loss: 1.0946 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 18/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.3714 - loss: 1.0944 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 19/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.3714 - loss: 1.0957 - val_accuracy: 0.3714 - val_loss: 1.0923
# Epoch 20/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3714 - loss: 1.0951 - val_accuracy: 0.3714 - val_loss: 1.0927
# Epoch 21/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - accuracy: 0.3683 - loss: 1.0945 - val_accuracy: 0.3714 - val_loss: 1.0926
# Epoch 22/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.3714 - loss: 1.0928 - val_accuracy: 0.3714 - val_loss: 1.0920
# Epoch 23/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.3714 - loss: 1.0952 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 24/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.3714 - loss: 1.0937 - val_accuracy: 0.3714 - val_loss: 1.0916
# Epoch 25/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.3651 - loss: 1.0915 - val_accuracy: 0.3714 - val_loss: 1.0894
# Epoch 26/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.4063 - loss: 1.0912 - val_accuracy: 0.3714 - val_loss: 1.0878
# Epoch 27/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.5810 - loss: 0.7273 - val_accuracy: 0.6000 - val_loss: 0.6992
# Epoch 50/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - accuracy: 0.6508 - loss: 0.6157 - val_accuracy: 0.6571 - val_loss: 0.6137
# pred: [ 0 23 12]
#
# [Fold 6]
# Epoch 1/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 125ms/step - accuracy: 0.3175 - loss: 1.1036 - val_accuracy: 0.3714 - val_loss: 1.0921
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.3429 - loss: 1.0964 - val_accuracy: 0.3714 - val_loss: 1.0932
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.3619 - loss: 1.0963 - val_accuracy: 0.3714 - val_loss: 1.0927
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.3683 - loss: 1.0945 - val_accuracy: 0.3714 - val_loss: 1.0926
# Epoch 5/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.3587 - loss: 1.0982 - val_accuracy: 0.3714 - val_loss: 1.0931
# Epoch 6/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - accuracy: 0.3619 - loss: 1.0958 - val_accuracy: 0.3714 - val_loss: 1.0933
# Epoch 7/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.3683 - loss: 1.0964 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 8/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3714 - loss: 1.0956 - val_accuracy: 0.3714 - val_loss: 1.0930
# Epoch 9/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.3270 - loss: 1.0951 - val_accuracy: 0.3714 - val_loss: 1.0932
# Epoch 10/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.3714 - loss: 1.0945 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 11/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.3714 - loss: 1.0935 - val_accuracy: 0.3714 - val_loss: 1.0928
# pred: [ 0 35  0]
#
# [Fold 7]
# Epoch 1/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 109ms/step - accuracy: 0.3778 - loss: 1.1001 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.3556 - loss: 1.0995 - val_accuracy: 0.3714 - val_loss: 1.0932
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.3714 - loss: 1.0983 - val_accuracy: 0.3714 - val_loss: 1.0933
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.3238 - loss: 1.0967 - val_accuracy: 0.3714 - val_loss: 1.0932
# Epoch 5/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.3714 - loss: 1.0946 - val_accuracy: 0.3714 - val_loss: 1.0926
# Epoch 6/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.3619 - loss: 1.0945 - val_accuracy: 0.4000 - val_loss: 1.0920
# Epoch 7/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3714 - loss: 1.0936 - val_accuracy: 0.3714 - val_loss: 1.0919
# Epoch 8/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3397 - loss: 1.0960 - val_accuracy: 0.3714 - val_loss: 1.0915
# Epoch 9/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - accuracy: 0.3619 - loss: 1.0968 - val_accuracy: 0.3714 - val_loss: 1.0934
# Epoch 10/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3460 - loss: 1.0956 - val_accuracy: 0.3714 - val_loss: 1.0921
# Epoch 11/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3556 - loss: 1.0942 - val_accuracy: 0.3714 - val_loss: 1.0883
# Epoch 12/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.3714 - loss: 1.0937 - val_accuracy: 0.3714 - val_loss: 1.0918
# Epoch 13/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3714 - loss: 1.0902 - val_accuracy: 0.3714 - val_loss: 1.0824
# Epoch 14/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.4000 - loss: 1.0666 - val_accuracy: 0.4571 - val_loss: 1.0582
# Epoch 15/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.4540 - loss: 1.0304 - val_accuracy: 0.3429 - val_loss: 1.1688
# Epoch 16/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - accuracy: 0.5175 - loss: 0.9674 - val_accuracy: 0.5143 - val_loss: 0.9890
# Epoch 17/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.5683 - loss: 0.8827 - val_accuracy: 0.4857 - val_loss: 1.0910
# Epoch 18/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.6063 - loss: 0.7689 - val_accuracy: 0.5143 - val_loss: 0.9443
# Epoch 19/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.5905 - loss: 0.7404 - val_accuracy: 0.5143 - val_loss: 0.8751
# Epoch 20/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.6254 - loss: 0.7010 - val_accuracy: 0.5143 - val_loss: 0.9094
# Epoch 21/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.5905 - loss: 0.6996 - val_accuracy: 0.5143 - val_loss: 0.9696
# Epoch 22/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.5619 - loss: 0.7364 - val_accuracy: 0.4857 - val_loss: 0.8653
# Epoch 23/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.6095 - loss: 0.7087 - val_accuracy: 0.4857 - val_loss: 0.8518
# Epoch 24/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.6063 - loss: 0.7041 - val_accuracy: 0.5143 - val_loss: 0.8733
# Epoch 25/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.6381 - loss: 0.6729 - val_accuracy: 0.4857 - val_loss: 0.8438
# Epoch 26/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.6254 - loss: 0.6647 - val_accuracy: 0.4857 - val_loss: 0.9412
# Epoch 27/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.6254 - loss: 0.6784 - val_accuracy: 0.5143 - val_loss: 0.8714
# Epoch 28/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.6159 - loss: 0.6980 - val_accuracy: 0.5429 - val_loss: 0.8326
# Epoch 29/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.6190 - loss: 0.6854 - val_accuracy: 0.5143 - val_loss: 0.8308
# Epoch 30/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step - accuracy: 0.6349 - loss: 0.6488 - val_accuracy: 0.5143 - val_loss: 0.8133
# Epoch 31/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.6476 - loss: 0.6501 - val_accuracy: 0.5143 - val_loss: 0.7935
# Epoch 32/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.6508 - loss: 0.6427 - val_accuracy: 0.5429 - val_loss: 0.7901
# Epoch 33/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.6159 - loss: 0.6512 - val_accuracy: 0.5429 - val_loss: 0.8414
# Epoch 34/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.6413 - loss: 0.6360 - val_accuracy: 0.5143 - val_loss: 0.8437
# Epoch 35/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.6571 - loss: 0.6112 - val_accuracy: 0.5429 - val_loss: 0.8153
# Epoch 36/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.6413 - loss: 0.6447 - val_accuracy: 0.5429 - val_loss: 0.7924
# Epoch 37/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.6254 - loss: 0.6203 - val_accuracy: 0.5143 - val_loss: 0.7899
# Epoch 38/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.6413 - loss: 0.6398 - val_accuracy: 0.5429 - val_loss: 0.8428
# Epoch 39/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.6571 - loss: 0.6103 - val_accuracy: 0.5429 - val_loss: 0.7740
# Epoch 40/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.6603 - loss: 0.6093 - val_accuracy: 0.5429 - val_loss: 0.8141
# Epoch 41/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.6444 - loss: 0.6299 - val_accuracy: 0.5429 - val_loss: 0.8270
# Epoch 42/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.6317 - loss: 0.6201 - val_accuracy: 0.5429 - val_loss: 0.8016
# Epoch 43/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.6667 - loss: 0.5934 - val_accuracy: 0.4857 - val_loss: 0.8305
# Epoch 44/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.6349 - loss: 0.6015 - val_accuracy: 0.5143 - val_loss: 0.7838
# Epoch 45/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.6667 - loss: 0.5739 - val_accuracy: 0.6000 - val_loss: 0.8539
# Epoch 46/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.6794 - loss: 0.5519 - val_accuracy: 0.4857 - val_loss: 0.8192
# Epoch 47/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.6889 - loss: 0.5924 - val_accuracy: 0.5714 - val_loss: 0.7764
# Epoch 48/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.7302 - loss: 0.5440 - val_accuracy: 0.4857 - val_loss: 0.8419
# Epoch 49/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.7048 - loss: 0.5457 - val_accuracy: 0.5429 - val_loss: 0.9138
# pred: [ 0 19 16]
#
# [Fold 8]
# Epoch 1/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 122ms/step - accuracy: 0.3397 - loss: 1.0997 - val_accuracy: 0.3714 - val_loss: 1.0930
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3302 - loss: 1.0969 - val_accuracy: 0.3714 - val_loss: 1.0933
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.3746 - loss: 1.0975 - val_accuracy: 0.3714 - val_loss: 1.0943
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.3143 - loss: 1.0954 - val_accuracy: 0.3714 - val_loss: 1.0933
# Epoch 5/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3810 - loss: 1.0944 - val_accuracy: 0.3714 - val_loss: 1.0922
# Epoch 6/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.3460 - loss: 1.0962 - val_accuracy: 0.3714 - val_loss: 1.0918
# Epoch 7/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3714 - loss: 1.0933 - val_accuracy: 0.3714 - val_loss: 1.0863
# Epoch 8/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3905 - loss: 1.0998 - val_accuracy: 0.3714 - val_loss: 1.0948
# Epoch 9/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.3714 - loss: 1.0953 - val_accuracy: 0.3714 - val_loss: 1.0932
# Epoch 10/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.3714 - loss: 1.0935 - val_accuracy: 0.3714 - val_loss: 1.0921
# Epoch 11/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3651 - loss: 1.0927 - val_accuracy: 0.3714 - val_loss: 1.0890
# Epoch 12/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.4635 - loss: 1.0811 - val_accuracy: 0.5143 - val_loss: 1.0538
# Epoch 13/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.5302 - loss: 0.9493 - val_accuracy: 0.3714 - val_loss: 1.2987
# Epoch 14/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.5778 - loss: 0.8486 - val_accuracy: 0.4857 - val_loss: 0.9723
# Epoch 15/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.5905 - loss: 0.7985 - val_accuracy: 0.4857 - val_loss: 1.0329
# Epoch 16/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.5937 - loss: 0.7997 - val_accuracy: 0.4857 - val_loss: 0.9895
# Epoch 17/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.5937 - loss: 0.7863 - val_accuracy: 0.4857 - val_loss: 0.9988
# Epoch 18/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - accuracy: 0.5905 - loss: 0.7881 - val_accuracy: 0.4857 - val_loss: 0.9924
# Epoch 19/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.5905 - loss: 0.8003 - val_accuracy: 0.4857 - val_loss: 0.9533
# Epoch 20/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.5905 - loss: 0.7918 - val_accuracy: 0.4857 - val_loss: 1.0025
# Epoch 21/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.5937 - loss: 0.7892 - val_accuracy: 0.4857 - val_loss: 0.9809
# Epoch 22/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.5937 - loss: 0.7708 - val_accuracy: 0.4857 - val_loss: 0.9621
# Epoch 23/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.5905 - loss: 0.7616 - val_accuracy: 0.4857 - val_loss: 0.9028
# Epoch 24/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.6063 - loss: 0.7372 - val_accuracy: 0.5429 - val_loss: 0.8909
# Epoch 25/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.6190 - loss: 0.7076 - val_accuracy: 0.6571 - val_loss: 0.7563
# Epoch 26/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.6413 - loss: 0.7005 - val_accuracy: 0.6000 - val_loss: 0.8203
# Epoch 27/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.6222 - loss: 0.6569 - val_accuracy: 0.5429 - val_loss: 0.8861
# Epoch 28/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.5968 - loss: 0.6781 - val_accuracy: 0.6571 - val_loss: 0.8043
# Epoch 29/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.6476 - loss: 0.6548 - val_accuracy: 0.6286 - val_loss: 0.8290
# Epoch 30/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.5778 - loss: 0.6563 - val_accuracy: 0.4857 - val_loss: 0.8656
# Epoch 31/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.6317 - loss: 0.6530 - val_accuracy: 0.6286 - val_loss: 0.8431
# Epoch 32/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.6317 - loss: 0.6709 - val_accuracy: 0.6000 - val_loss: 0.8694
# Epoch 33/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.6254 - loss: 0.6769 - val_accuracy: 0.6571 - val_loss: 0.7796
# Epoch 34/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.6317 - loss: 0.6609 - val_accuracy: 0.6571 - val_loss: 0.7594
# Epoch 35/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.6095 - loss: 0.7001 - val_accuracy: 0.6286 - val_loss: 0.8300
# pred: [ 0 23 12]
#
# [Fold 9]
# Epoch 1/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 146ms/step - accuracy: 0.3111 - loss: 1.1053 - val_accuracy: 0.3714 - val_loss: 1.0936
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.3778 - loss: 1.0959 - val_accuracy: 0.3714 - val_loss: 1.0936
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.3714 - loss: 1.0952 - val_accuracy: 0.3714 - val_loss: 1.0927
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - accuracy: 0.3778 - loss: 1.0967 - val_accuracy: 0.3714 - val_loss: 1.0927
# Epoch 5/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.3524 - loss: 1.0941 - val_accuracy: 0.3714 - val_loss: 1.0913
# Epoch 6/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.3778 - loss: 1.0945 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 7/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.3714 - loss: 1.0944 - val_accuracy: 0.3714 - val_loss: 1.0921
# Epoch 8/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.3714 - loss: 1.0941 - val_accuracy: 0.3714 - val_loss: 1.0922
# Epoch 9/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.3905 - loss: 1.0900 - val_accuracy: 0.3143 - val_loss: 1.0766
# Epoch 10/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.3587 - loss: 1.0951 - val_accuracy: 0.3714 - val_loss: 1.0867
# Epoch 11/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.3683 - loss: 1.1029 - val_accuracy: 0.3714 - val_loss: 1.0951
# Epoch 12/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.3778 - loss: 1.0957 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 13/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3746 - loss: 1.0963 - val_accuracy: 0.3714 - val_loss: 1.0932
# Epoch 14/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.3714 - loss: 1.0942 - val_accuracy: 0.3714 - val_loss: 1.0931
# Epoch 15/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.3714 - loss: 1.0944 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 16/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3714 - loss: 1.0948 - val_accuracy: 0.3714 - val_loss: 1.0927
# Epoch 17/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3714 - loss: 1.0951 - val_accuracy: 0.3714 - val_loss: 1.0925
# Epoch 18/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step - accuracy: 0.3714 - loss: 1.0948 - val_accuracy: 0.3714 - val_loss: 1.0930
# Epoch 19/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.3460 - loss: 1.0956 - val_accuracy: 0.3714 - val_loss: 1.0931
# pred: [ 0  2 33]
#
# [Fold 10]
# Epoch 1/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.3714 - loss: 1.1005 - val_accuracy: 0.3714 - val_loss: 1.0967
# Epoch 2/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3714 - loss: 1.0970 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 3/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.3746 - loss: 1.0957 - val_accuracy: 0.3714 - val_loss: 1.0933
# Epoch 4/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.3683 - loss: 1.0951 - val_accuracy: 0.3714 - val_loss: 1.0923
# Epoch 5/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step - accuracy: 0.3714 - loss: 1.0941 - val_accuracy: 0.3714 - val_loss: 1.0927
# Epoch 6/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.3619 - loss: 1.0938 - val_accuracy: 0.3429 - val_loss: 1.0898
# Epoch 7/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.3714 - loss: 1.1004 - val_accuracy: 0.3714 - val_loss: 1.0943
# Epoch 8/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.3714 - loss: 1.0957 - val_accuracy: 0.3714 - val_loss: 1.0930
# Epoch 9/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.3556 - loss: 1.0960 - val_accuracy: 0.3714 - val_loss: 1.0932
# Epoch 10/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.3460 - loss: 1.0968 - val_accuracy: 0.3714 - val_loss: 1.0931
# Epoch 11/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.3714 - loss: 1.0947 - val_accuracy: 0.3714 - val_loss: 1.0932
# Epoch 12/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - accuracy: 0.3714 - loss: 1.0944 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 13/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.3714 - loss: 1.0954 - val_accuracy: 0.3714 - val_loss: 1.0929
# Epoch 14/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.3714 - loss: 1.0945 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 15/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.3714 - loss: 1.0934 - val_accuracy: 0.3714 - val_loss: 1.0928
# Epoch 16/80
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.3683 - loss: 1.0986 - val_accuracy: 0.3714 - val_loss: 1.0929
# pred: [ 0 34  1]
# Model with conv_filters=64 and lstm_units=64 saved as 'violence_detection_model_conv_64_lstm_64.h5'
# Average F1-Score: 0.4186
# Average AUC: 0.7710

# %% [markdown]
# ### 4. Plot the results

# %%
import numpy as np
import matplotlib.pyplot as plt

# Get the length of the longest history record
max_len = max([len(history['loss']) for key in results_neurons for history in results_neurons[key]['histories']])

# Define a function to pad history records
def pad_history(history, max_len):
    padded_history = {}
    for key in history:
        padded_history[key] = history[key] + [history[key][-1]] * (max_len - len(history[key]))
    return padded_history

# Pad all history records
padded_results_neurons = {}
for key in results_neurons:
    padded_histories = [pad_history(history, max_len) for history in results_neurons[key]['histories']]
    padded_results_neurons[key] = {
        'histories': padded_histories,
        'mean_fpr': results_neurons[key]['mean_fpr'],
        'mean_tpr': results_neurons[key]['mean_tpr'],
        'mean_auc_curve': results_neurons[key]['mean_auc_curve']
    }

# Plot training loss
plt.figure(figsize=(12, 6))
for key in padded_results_neurons:
    mean_loss = np.mean([history['loss'] for history in padded_results_neurons[key]['histories']], axis=0)
    plt.plot(mean_loss, label=f'Training {key}')
plt.title('Training Loss for Different Configurations')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot validation loss
plt.figure(figsize=(12, 6))
for key in padded_results_neurons:
    mean_val_loss = np.mean([history['val_loss'] for history in padded_results_neurons[key]['histories']], axis=0)
    plt.plot(mean_val_loss, label=f'Validation {key}')
plt.title('Validation Loss for Different Configurations')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training accuracy
plt.figure(figsize=(12, 6))
for key in padded_results_neurons:
    mean_accuracy = np.mean([history['accuracy'] for history in padded_results_neurons[key]['histories']], axis=0)
    plt.plot(mean_accuracy, label=f'Training {key}')
plt.title('Training Accuracy for Different Configurations')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot validation accuracy
plt.figure(figsize=(12, 6))
for key in padded_results_neurons:
    mean_val_accuracy = np.mean([history['val_accuracy'] for history in padded_results_neurons[key]['histories']], axis=0)
    plt.plot(mean_val_accuracy, label=f'Validation {key}')
plt.title('Validation Accuracy for Different Configurations')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot ROC curve
plt.figure(figsize=(12, 6))
for key in padded_results_neurons:
    mean_fpr = padded_results_neurons[key]['mean_fpr']
    mean_tpr = padded_results_neurons[key]['mean_tpr']
    mean_auc = padded_results_neurons[key]['mean_auc_curve']
    plt.plot(mean_fpr, mean_tpr, label=f'{key} (AUC = {mean_auc:.2f})')

plt.plot([0, 1], [0, 1], color='r', linestyle='--')
plt.title('Receiver Operating Characteristic (ROC)')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.show()

# %%
save_dir = BASE_DIR / "train_weight"
save_dir.mkdir(parents=True, exist_ok=True)

conv_filters=64
lstm_units=64

model = create_model(input_shape, num_classes, conv_filters, lstm_units)
model.fit(data, targets, epochs=25, batch_size=8)
model.save(save_dir / f'violence_detection_model_conv_{conv_filters}_lstm_{lstm_units}_revisedv1.h5')
print(f"Model with conv_filters={conv_filters} and lstm_units={lstm_units} saved.")
