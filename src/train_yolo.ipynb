# %% [markdown]
# ### 1. Training the Yolo model

# %%
import ultralytics
ultralytics.checks()

from ultralytics import YOLO
from IPython.display import display, Image

from roboflow import Roboflow 

from pathlib import Path

import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.environ["TORCH_SHOW_CPP_STACKTRACES"] = "1"
# Out:
# Ultralytics 8.4.21  Python-3.12.3 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5080 Laptop GPU, 16303MiB)
# Setup complete  (32 CPUs, 31.2 GB RAM, 350.6/1863.0 GB disk)

# %% [markdown]
# Download the dataset from roboflow directly or run the following code. For convenience, the downloaded file store in data/roboflow.

# %%
# rf = Roboflow(api_key="UyzTs9NNpinC2TGfXmXc")
# project = rf.workspace("gakings-workspace").project("violence-detection-nbx24-aowtv")
# version = project.version(1)
# dataset = version.download("yolov8")

# rf = Roboflow(api_key="UyzTs9NNpinC2TGfXmXc")
# project = rf.workspace("gakings-workspace").project("violence-detection-nbx24-aowtv")
# version = project.version(2)
# dataset = version.download("yolov8")
                
# rf = Roboflow(api_key="UyzTs9NNpinC2TGfXmXc")
# project = rf.workspace("gakings-workspace").project("violence-detection-nbx24-aowtv")
# version = project.version(3)
# dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Violence-Detection-3 in yolov8:: 100%|██████████| 31708/31708 [00:11<00:00, 2858.61it/s]

# %% [markdown]
# Train the yolo model

# %%
BASE_DIR = Path.cwd().parent
print(f"Base directory: {BASE_DIR}")
# Out:
# Base directory: d:\Myworkplace\Python\violence-movies

# %%
BASE_DIR = Path.cwd().parent

data_path = BASE_DIR / "data/roboflow/Violence-Detection-3/data.yaml"
yolo_weight_path = BASE_DIR / "yolo_weight"

model = YOLO(yolo_weight_path / "yolov8s.pt")
results = model.train(
    data=data_path,
    epochs=120,
    imgsz=640,
    batch=24,
    device=0,
    workers=8,
    name='train_yolov8s_' + "violence" + "_v3",
    verbose=True
)
# Out:
# Ultralytics 8.3.252  Python-3.11.2 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 8188MiB)
# ...
